# %%
# ==============================================================================
# COURS DATA SCIENCE : CYCLE DE VIE COMPLET (SCRIPT PÉDAGOGIQUE)
# Auteur : Votre Professeur IA
# ==============================================================================

# ------------------------------------------------------------------------------
# 1. IMPORTATION DES BIBLIOTHÈQUES
# ------------------------------------------------------------------------------
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import kagglehub   # <--- import nécessaire

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

sns.set_theme(style="whitegrid")
import warnings
warnings.filterwarnings('ignore')

print("1. Bibliothèques importées avec succès.\n")

# ------------------------------------------------------------------------------
# 2. CHARGEMENT DU DATASET HEART DISEASE
# ------------------------------------------------------------------------------
print("2. Téléchargement et chargement du dataset Heart Disease...")

path = kagglehub.dataset_download("johnsmith88/heart-disease-dataset")
df = pd.read_csv(path + "/heart.csv")

print(f"   Données chargées. Taille du dataset : {df.shape}\n")
print(df.head())

# ------------------------------------------------------------------------------
# 3. SIMULATION DE DONNÉES SALES
# ------------------------------------------------------------------------------
print("\n3. Introduction artificielle de NaN...")

np.random.seed(42)
df_dirty = df.copy()

for col in df.columns:
    if col != "target":
        df_dirty.loc[df_dirty.sample(frac=0.05).index, col] = np.nan

print("   Nombre total de NaN générés :", df_dirty.isnull().sum().sum(), "\n")

# ------------------------------------------------------------------------------
# 4. NETTOYAGE / PREPARATION
# ------------------------------------------------------------------------------
print("4. Nettoyage...")

X = df_dirty.drop("target", axis=1)
y = df_dirty["target"]

imputer = SimpleImputer(strategy="mean")
X_clean = pd.DataFrame(imputer.fit_transform(X), columns=X.columns)

print("   Imputation terminée. NaN restants :", X_clean.isnull().sum().sum(), "\n")

# ------------------------------------------------------------------------------
# 5. ANALYSE EXPLORATOIRE (EDA)
# ------------------------------------------------------------------------------
print("5. Analyse Exploratoire...")

print("   Statistiques descriptives (5 premières colonnes) :")
print(X_clean.iloc[:, :5].describe(), "\n")

# Heatmap de corrélation
plt.figure(figsize=(10, 8))
sns.heatmap(X_clean.iloc[:, :10].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Matrice de Corrélation (Top 10 Features)")
plt.show()

# ------------------------------------------------------------------------------
# 6. TRAIN / TEST SPLIT
# ------------------------------------------------------------------------------
X_train, X_test, y_train, y_test = train_test_split(
    X_clean, y, test_size=0.2, random_state=42
)

print("6. Split effectué :")
print(f"   Train : {X_train.shape[0]} lignes")
print(f"   Test  : {X_test.shape[0]} lignes\n")

# ------------------------------------------------------------------------------
# 7. MODELE MACHINE LEARNING
# ------------------------------------------------------------------------------
print("7. Entraînement du modèle Random Forest...")

model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

print("   Modèle entraîné.\n")

# ------------------------------------------------------------------------------
# 8. EVALUATION DU MODELE
# ------------------------------------------------------------------------------
print("8. Évaluation...")

y_pred = model.predict(X_test)

print(f"   >>> Accuracy : {accuracy_score(y_test, y_pred)*100:.2f}%\n")

print("   >>> Rapport de classification :")
print(classification_report(y_test, y_pred,
                            target_names=["No Disease", "Disease"]))

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=["0 (Pas de maladie)", "1 (Maladie)"],
            yticklabels=["0 (Pas de maladie)", "1 (Maladie)"])
plt.title("Matrice de Confusion")
plt.xlabel("Prédiction")
plt.ylabel("Réalité")
plt.show()

print("\n--- FIN DU SCRIPT ---")
# Out:
# 1. Bibliothèques importées avec succès.
#
# 2. Téléchargement et chargement du dataset Heart Disease...
# Using Colab cache for faster access to the 'heart-disease-dataset' dataset.
#    Données chargées. Taille du dataset : (1025, 14)
#
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
#
# 3. Introduction artificielle de NaN...
#    Nombre total de NaN générés : 663
#
# 4. Nettoyage...
# ...

# %%
# ------------------------------------------------------------------------------
#

 "MEAN RADIUS"
# ------------------------------------------------------------------------------

plt.figure(figsize=(10,5))

sns.histplot(
    data=df,
    x="age",
    hue="target",
    kde=True,
    element="step",
    palette=["blue", "orange"],
    alpha=0.4
)

plt.title("Distribution de l'âge selon la présence de maladie (0 = sain, 1 = malade)")
plt.xlabel("Âge")
plt.ylabel("Nombre")
plt.show()
